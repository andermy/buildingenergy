# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Laster inn energidata fra Statsbygg EOS
power = pd.read_excel('Brann og kirke.xls')
#powerHeat = pd.read_excel('Kjelkraft.xls')
# Laster inn utetemperaturer
#utetemp = pd.read_excel('table (1).xlsx')

# %%
power.columns = ['date', 'power', 'nn', 'nn2', 'nn3', 'nn4', 'Temp']
power = power[['date', 'power', 'Temp']]
power = power[4:]
power.date = power.date.str.slice(stop=16)
power['date'] = pd.to_datetime(power['date'], format='%d.%m.%Y %H:%M')
power['weekday'] = power.date.dt.weekday
power['month'] = power.date.dt.month
power['hour'] = power.date.dt.hour
power = power.set_index('date')

#power = powerNonHeat.merge(powerHeat.powerHeat, left_index=True, right_index=True)
#power['totPower'] = power.power  + power.powerHeat
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b97d83de38e1> in <module>
# ----> 1 power.columns = ['date', 'power', 'nn', 'nn2', 'nn3', 'nn4', 'Temp']
#       2 power = power[['date', 'power', 'Temp']]
#       3 power = power[4:]
#       4 power.date = power.date.str.slice(stop=16)
#       5 power['date'] = pd.to_datetime(power['date'], format='%d.%m.%Y %H:%M')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 5 elements, new values have 7 elements

# %%
power.head()
# Out:
#                     power Temp  weekday  month  hour powerHeat totPower
# date
# 2021-01-01 00:00:00  54.3 -6.1        4      1     0      62.2    116.5
# 2021-01-01 01:00:00  55.2 -6.4        4      1     1      64.6    119.8
# 2021-01-01 02:00:00  53.4 -6.4        4      1     2      63.2    116.6
# 2021-01-01 03:00:00  54.3 -6.7        4      1     3      64.2    118.5
# 2021-01-01 04:00:00  53.4 -6.4        4      1     4      62.4    115.8

# %%
energyModel = {}
powerModel = {}
runTimeModel = {}

# %%
# Graf over energiforbruk i angitt periode
# NB! Hoppene man ser med jevnlige mellomrom i grafen under skyldes hull i tidsserien. Jobber med å finne en løsning
#power = power.set_index(['date'])
power['powerHeat'].plot()

plt.xlabel('Dato - 2021')
plt.ylabel('Energiforbruk [kWh/h]')

# Tittel
plt.title('Energiforbruk 2021')
#plt.legend()
print("Fast minimum effektforbruk [kW] er: ")
power['totPower'].min()
# Out:
# Fast minimum effektforbruk [kW] er:
# 30.3

# %%
energyModel['Pumper'] = round(5 * 8760,0) # Sett inn antall kW pumper
energyModel['Server'] = round((power['totPower'].min()-5)/3.5*2.5 * 8760,0)
energyModel['Kjøling'] = round((power['totPower'].min()-5)/3.5*1 * 8760,0)
powerModel['Fixed'] = round(power['totPower'].min(),0)
runTimeModel['Fixed'] = 8760

# %%
power['totPower'].sum()
# Out:
# 802408.2999999975

# %%
# Døgnplott for valgt måler
power.plot.scatter(x='hour', y='power');
plt.xlabel('Klokkeslett')
plt.ylabel('Energiforbruk [kWh/h]')
 
# Tittel
plt.title('Døgnplott for 2021')
#plt.legend()
# Out:
# Text(0.5, 1.0, 'Døgnplott for 2021')

# %%
power2 = power[power.weekday==4]
powerDay = power2.resample('D')['power'].min()
powerDay = powerDay.resample('H').ffill()
power2 = power2.merge(powerDay.rename('new'), left_index=True, right_index=True, how='outer')
#power2 = power[power['Temp'] <19]
power2['pDiff'] = power2.power-power2.new
power2.between_time('10:00', '14:00').plot.scatter(x='Temp', y='pDiff')
# Out:
# <AxesSubplot:xlabel='Temp', ylabel='pDiff'>

# %%
# Sett inn min/ maks verdier
powerVentMax = 70
powerVentMin = 0
tempVentMax = -20
tempVentMin = 15
weekhours = 9*5+4*2

# %%
# Ukeplott for angitt måler
# Aktuelt for å sjekke varisjoner i drift (helg og evt. spesielle ukedager)
power.plot.scatter(x='weekday', y='powerHeat')
plt.xticks([0,1,2,3,4,5,6],['Man', 'Tir', 'Ons', 'Tor', 'Fre', 'Lør', 'Søn'])
plt.xlabel('Ukedag')
plt.ylabel('Energiforbruk [kWh/h]')
 
# Tittel
plt.title('Ukeplott for Malvik Rådhus')
#plt.legend()
# Out:
# Text(0.5, 1.0, 'Ukeplott for Malvik Rådhus')

# %%
power[power.hour==4].plot.scatter(x='Temp', y='power')
plt.xlabel('Utetemperatur [C]')
plt.ylabel('Energiforbruk [kWh/h]')
 
# Tittel
plt.title('ET-kurve natt (04:00) for Malvik Rådhus')
#plt.legend()
# Out:
# Text(0.5, 1.0, 'ET-kurve natt (04:00) for Malvik Rådhus')

# %%
powerVarmeMax = 110
powerVarmeMin = 0
tempVarmeMax = 15
tempVarmeMin = -20
powerVK = 10
tempVK = 3
